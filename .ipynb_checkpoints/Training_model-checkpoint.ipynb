# %%
import os
import numpy as np
import pandas as pd

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/test'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
train.head(10)
# Out:
#                           image  label
# 0      images/train\angry\0.jpg  angry
# 1      images/train\angry\1.jpg  angry
# 2     images/train\angry\10.jpg  angry
# 3  images/train\angry\10002.jpg  angry
# 4  images/train\angry\10016.jpg  angry
# 5  images/train\angry\10037.jpg  angry
# 6  images/train\angry\10038.jpg  angry
# 7  images/train\angry\10057.jpg  angry
# 8  images/train\angry\10063.jpg  angry
# 9  images/train\angry\10069.jpg  angry

# %%
train.tail()
# Out:
#                                 image     label
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]

# %%
print("\nTotal train images:", len(train))
# Convert label counts into a DataFrame
label_counts = train['label'].value_counts().reset_index()

# Rename the columns
label_counts.columns = ['Label', 'Count']

# Display like df.head()
label_counts.head(10)
# Out:
# Total train images: 28821
#       Label  Count
# 0     happy   7164
# 1   neutral   4982
# 2       sad   4938
# 3      fear   4103
# 4     angry   3993
# 5  surprise   3205
# 6   disgust    436

# %%
#Count of test dataset
print("\nTest dataset statistics:")
print(test['label'].value_counts())
print("\nTotal test images:", len(test))
# Out:
# Test dataset statistics:
# label
# happy       1825
# neutral     1216
# sad         1139
# fear        1018
# angry        960
# surprise     797
# disgust      111
# Name: count, dtype: int64
#
# Total test images: 7066

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, color_mode="grayscale")
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))
# Out:
# C:\Users\nikhi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'] )

# %%
model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 188s 820ms/step - accuracy: 0.2301 - loss: 1.8396 - val_accuracy: 0.2583 - val_loss: 1.8145
# Epoch 2/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 726ms/step - accuracy: 0.2459 - loss: 1.8126 - val_accuracy: 0.2641 - val_loss: 1.7793
# Epoch 3/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 165s 731ms/step - accuracy: 0.2608 - loss: 1.7726 - val_accuracy: 0.3160 - val_loss: 1.6800
# Epoch 4/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 165s 728ms/step - accuracy: 0.3119 - loss: 1.6910 - val_accuracy: 0.4192 - val_loss: 1.5032
# Epoch 5/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 159s 703ms/step - accuracy: 0.3937 - loss: 1.5485 - val_accuracy: 0.4578 - val_loss: 1.3890
# Epoch 6/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 171s 758ms/step - accuracy: 0.4239 - loss: 1.4773 - val_accuracy: 0.4806 - val_loss: 1.3452
# Epoch 7/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 195s 862ms/step - accuracy: 0.4495 - loss: 1.4327 - val_accuracy: 0.5004 - val_loss: 1.3019
# Epoch 8/100
# ...

# %%
model_json = model.to_json()
with open("emotiondetector.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import model_from_json

# %%
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.json")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image, color_mode="grayscale", target_size=(48,48))  # fixed
    feature = np.array(img)
    feature = feature.reshape(1, 48, 48, 1)   # batch size, height, width, channel
    return feature / 255.0

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# model prediction is  sad

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# model prediction is  sad

# %%
image = 'images/train/fear/17.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# model prediction is  fear

# %%
image = 'images/train/disgust/299.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# model prediction is  disgust

# %%
image = 'images/train/happy/7.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# model prediction is  happy

# %%
image = 'images/train/surprise/15.jpg'
print("original image is of surprise")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# model prediction is  surprise

# %%
# Shape of dataset
print("Train shape:", train.shape)
print("Test shape:", test.shape)

# Data types
print("\nData Types:\n", train.dtypes)

# Show first 5 rows
print("\nSample Training Data:\n", train.head())
# Out:
# Train shape: (28821, 2)
# Test shape: (7066, 2)
#
# Data Types:
#  image    object
# label    object
# dtype: object
#
# Sample Training Data:
#                            image  label
# 0      images/train\angry\0.jpg  angry
# 1      images/train\angry\1.jpg  angry
# 2     images/train\angry\10.jpg  angry
# 3  images/train\angry\10002.jpg  angry
# 4  images/train\angry\10016.jpg  angry

# %%
# Count per class
train_counts = train['label'].value_counts()

# Statistics
print("Mean:", train_counts.mean())
print("Median:", train_counts.median())
print("Mode:", train_counts.mode()[0])
print("Min:", train_counts.min())
print("Max:", train_counts.max())
print("Range:", train_counts.max() - train_counts.min())
print("Standard Deviation:", train_counts.std())
# Out:
# Mean: 4117.285714285715
# Median: 4103.0
# Mode: 436
# Min: 436
# Max: 7164
# Range: 6728
# Standard Deviation: 2045.464553126071

# %%
import pandas as pd

# Count per class
train_counts = train['label'].value_counts()

# ✅ Stats dictionary (manual + describe in one place)
stats = {
    "Mean": train_counts.mean(),
    "Median": train_counts.median(),
    "Mode": train_counts.mode()[0],
    "Min": train_counts.min(),
    "Max": train_counts.max(),
    "Range": train_counts.max() - train_counts.min(),
    "Standard Deviation": train_counts.std(),
    "Count": train_counts.count(),     # from describe
    "25%": train_counts.quantile(0.25),
    "50%": train_counts.quantile(0.50),
    "75%": train_counts.quantile(0.75),
}

# ✅ Convert to DataFrame (box format like .head())
stats_df = pd.DataFrame(list(stats.items()), columns=["Statistic", "Value"])
stats_df
# Out:
#              Statistic        Value
# 0                 Mean  4117.285714
# 1               Median  4103.000000
# 2                 Mode   436.000000
# 3                  Min   436.000000
# 4                  Max  7164.000000
# 5                Range  6728.000000
# 6   Standard Deviation  2045.464553
# 7                Count     7.000000
# 8                  25%  3599.000000
# 9                  50%  4103.000000
# 10                 75%  4960.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd
from keras.preprocessing import image

# ✅ Extract simple features (mean, std, height, width, area)
def extract_features(df):
    features = []
    for img_path in df['image']:
        try:
            img = image.load_img(img_path, target_size=(48,48), color_mode="grayscale")  # resize
            img_array = image.img_to_array(img).astype('float32') / 255.0  # normalize
            
            # Basic pixel stats
            mean_val = np.mean(img_array)
            std_val = np.std(img_array)
            
            # Image shape info
            height, width = img_array.shape[0], img_array.shape[1]
            area = height * width   # total pixel count
            
            features.append([mean_val, std_val, height, width, area])
        except:
            features.append([None, None, None, None, None])  # bad image
    return pd.DataFrame(features, columns=['mean_pixel','std_pixel','height','width','area'])

# ✅ Build features dataframe
feat_df = extract_features(train)
feat_df['label'] = train['label']   # attach labels
feat_df.head()
# Out:
#    mean_pixel  std_pixel  height  width  area  label
# 0    0.461200   0.199153      48     48  2304  angry
# 1    0.497975   0.160345      48     48  2304  angry
# 2    0.438200   0.196951      48     48  2304  angry
# 3    0.475385   0.269467      48     48  2304  angry
# 4    0.551753   0.224833      48     48  2304  angry

# %%
plt.figure(figsize=(8,5))
plt.hist(feat_df['mean_pixel'].dropna(), bins=35, edgecolor='black', alpha=0.7)
plt.title("Distribution of Mean Pixel Brightness")
plt.xlabel("Mean Pixel Value")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
train_counts.plot(kind='bar', color='skyblue')
plt.title("Bar Chart - Emotion Categories")
plt.xlabel("Emotion")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,6))
train_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title("Pie Chart of Emotions (Train Set)")
plt.ylabel("") 
plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Define output directory
OUTPUT_DIR = "./outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Define the manual order of emotions
order = ["angry", "sad", "happy", "fear", "surprise", "neutral", "disgust"]

#  Boxplot of mean pixel brightness grouped by emotion
plt.figure(figsize=(10,5))
plt.boxplot(
    [feat_df.loc[feat_df['label'] == emo, 'mean_pixel'].dropna() for emo in order],
    tick_labels=order,   # use tick_labels (new parameter)
    patch_artist=True,
    boxprops=dict(facecolor="skyblue", color="black"),
    medianprops=dict(color="red", linewidth=2),
    whiskerprops=dict(color="black"),
    capprops=dict(color="black"),
    flierprops=dict(marker="o", markerfacecolor="gray", markersize=4, linestyle="none")
)

plt.title("Mean Pixel Brightness by Emotion (Boxplot)")
plt.xlabel("Emotion")
plt.ylabel("Mean Pixel Brightness")
plt.xticks(rotation=45)
plt.tight_layout()

#  Save & show
plt.savefig(os.path.join(OUTPUT_DIR,"mean_pixel_boxplot.png"), dpi=200)
plt.show()

# %%
plt.figure(figsize=(8,5))
train_counts.sort_values().cumsum().plot(kind='line', marker='o')
plt.title("Line Chart - Cumulative Class Counts")
plt.xlabel("Class (sorted)")
plt.ylabel("Cumulative Count")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

sample_df = feat_df.dropna().sample(n=200, random_state=42)

X = sample_df[['mean_pixel', 'std_pixel']].values
y = sample_df['label'].values

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8,6))
for label in np.unique(y):
    idx = y == label
    plt.scatter(X_pca[idx,0], X_pca[idx,1], label=label, alpha=0.7, s=40)

plt.title("PCA 2D Projection (Sample of 100 Images)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
import os

# ✅ Sample 200 images
sample_df = feat_df.dropna().sample(n=200, random_state=42)

X = sample_df[['mean_pixel', 'std_pixel']].values
y = sample_df['label'].values

# ✅ PCA transformation
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# ✅ Scatter plot
plt.figure(figsize=(8,6))
for label in np.unique(y):
    idx = y == label
    plt.scatter(X_pca[idx,0], X_pca[idx,1], label=label, alpha=0.7, s=40)

plt.title("PCA 2D Projection (Sample of 200 Images)")
plt.legend()
plt.tight_layout()

# ✅ Save to Downloads (like bar plot saving)
save_path = os.path.expanduser("~/Downloads/pca_scatter_plot.png")
plt.savefig(save_path, dpi=200)
plt.show()

print(f"✅ Scatter plot saved at: {save_path}")
# Out:
# ✅ Scatter plot saved at: C:\Users\nikhi/Downloads/pca_scatter_plot.png
